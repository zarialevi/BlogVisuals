# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_style("dark")
tips = sns.load_dataset("diamonds")
plt.ylim(3300, 4675)
ax = sns.barplot(x="cut", y="price", data=tips, palette='PuBu')

plt.savefig('img1.png')

# %%
sns.set_style("dark")
tips = sns.load_dataset("diamonds")
plt.ylim(0, 10000)
ax = sns.barplot(x="cut", y="price", data=tips, palette='PuBu')

plt.savefig('img2.png')
